# %%
import os
import fitz  # PyMuPDF
from typing import Union
import threading
import pandas as pd
import random
import numpy as np
import cv2

from typing import Dict, List, Tuple
from docsumo_image_util.parse.ocr.google import read_data, read_everything
from docsumo_image_util.parse.pdf2img import PdfImages
from dotenv import load_dotenv
load_dotenv() 
# Create a lock for token updates
token_lock = threading.Lock()
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "/media/veracrypt1/GAC.json"
# from app.config import config_by_name
# Out:
# 2025-05-04 00:29:51.966 | WARNING  | docsumo_image_util.parse.ocr.google:<module>:47 - GOOGLE_APPLICATION_CREDENTIALS was not set. Make sure you have configured Application Default Credentials.
# 2025-05-04 00:29:51.967 | WARNING  | docsumo_image_util.parse.ocr.google:<module>:50 - Set base64 of service account json as GOOGLE_APPLICATION_CREDENTIALS on docker. If local, set above env as json path
# 2025-05-04 00:29:51.969 | WARNING  | docsumo_image_util.parse.ocr.ms:<module>:29 - Azure Subscription key not found...
# 2025-05-04 00:29:51.970 | WARNING  | docsumo_image_util.parse.ocr.ms:<module>:33 - Azure Region not found...
# 2025-05-04 00:29:51.971 | WARNING  | docsumo_image_util.parse.ocr.ms:<module>:37 - Azure Computer Vision Endpoint not found...

# %%
# Root directory where all folders are located
base_dir = os.getcwd()

# Folders to process
folders = ['Invoice', 'Form 1040', 'Form 1040 A', 'Form 1040 B', 'Form 1040 C', 'Form 1040 D', 'Form 1040 E', 'W9', 'Acord 25']
page_counts = {}

# Iterate through each folder and PDF inside
for folder in folders:
    folder_path = os.path.join(base_dir, folder)
    if not os.path.isdir(folder_path):
        print(f"[WARNING] Folder not found: {folder_path}")
        continue

    for filename in os.listdir(folder_path):
        if filename.lower().endswith('.pdf'):
            file_path = os.path.join(folder_path, filename)
            try:
                doc = fitz.open(file_path)
                num_pages = len(doc)
                doc.close()

                key = f"{folder}/{filename}"
                page_counts[key] = num_pages

                print(f"[INFO] {key}: {num_pages} pages")
            except Exception as e:
                print(f"[ERROR] Failed to open {file_path}: {e}")
                page_counts[f"{folder}/{filename}"] = 1  # fallback

# Optional: print the summary
print("\n=== Summary ===")
for key, count in page_counts.items():
    print(f"{key}: {count} pages")
# Out:
# [INFO] Invoice/page_19_invoice_10_10.pdf: 1 pages
# [INFO] Invoice/page_20_invoice_7_7.pdf: 1 pages
# [INFO] Invoice/page_19_invoice_3_3.pdf: 1 pages
# [INFO] Invoice/page_20_invoice_17_17.pdf: 1 pages
# [INFO] Invoice/page_19_invoice_17_17.pdf: 1 pages
# [INFO] Form 1040/document (25)_2_3.pdf: 2 pages
# [INFO] Form 1040/2022 UNFILED tax return_2_3.pdf: 2 pages
# [INFO] Form 1040/form_1040.pdf: 2 pages
# [INFO] Form 1040/sample_form_1040.pdf: 2 pages
# [INFO] Form 1040/foxtheresa_22i_FC(1)_10_11.pdf: 2 pages
# [INFO] Form 1040 A/Heisey, Matthew D_7_7.pdf: 1 pages
# [INFO] Form 1040 A/document (3)_9_9.pdf: 1 pages
# [INFO] Form 1040 A/Kennedy_15_15.pdf: 1 pages
# [INFO] Form 1040 A/2020 Tax Return_9_9.pdf: 1 pages
# [INFO] Form 1040 A/Reyes 1040 2021_3_3.pdf: 1 pages
# [INFO] Form 1040 B/sample_form_1040_schedule_b.pdf: 1 pages
# [INFO] Form 1040 B/2022 Tax Return Documents (Warner Theodore L and J - Client Copy) (3)_8_8.pdf: 1 pages
# [INFO] Form 1040 B/RJ_Roberts_1040_2021 taxes_13_13.pdf: 1 pages
# [INFO] Form 1040 B/Dina & Chris combined 1040_6_6.pdf: 1 pages
# [INFO] Form 1040 B/MARLON and SALLY REYES 2022 Client Copy_9_9.pdf: 1 pages
# [INFO] Form 1040 C/2022 Tax Return_Acosta, Juan and Jeanette Favela_30_31.pdf: 2 pages
# [INFO] Form 1040 C/2021 Tax Return Documents (Volovik Inna and Aleksa - Client Copy)_20_21.pdf: 2 pages
# [INFO] Form 1040 C/document (3)_13_14.pdf: 2 pages
# [INFO] Form 1040 C/Heisey, Matthew D_9_10.pdf: 2 pages
# [INFO] Form 1040 C/2022 George Garner_21_22.pdf: 2 pages
# [INFO] Form 1040 D/2021 Tax Return Documents (Volovik Inna and Aleksa - Client Copy)_24_25.pdf: 2 pages
# [INFO] Form 1040 D/JEREZ TAX 2021_15_16.pdf: 2 pages
# [INFO] Form 1040 D/document (3)_removed_16_17.pdf: 2 pages
# [INFO] Form 1040 D/2022 Tax Return_Acosta, Juan and Jeanette Favela_33_34.pdf: 2 pages
# [INFO] Form 1040 D/Forgie, Michael_16_17.pdf: 2 pages
# [INFO] Form 1040 E/2022 Tax Return Documents (MCDONALD STANTON H and) draft_15_16.pdf: 2 pages
# [INFO] Form 1040 E/GTI to PDF Conversion -- 2ce88f36-eec2-f518-1afa-e0f52c16c359_7_8.pdf: 2 pages
# [INFO] Form 1040 E/2021.1040.Maciak_18_19.pdf: 2 pages
# [INFO] Form 1040 E/Heisey, Matthew D_11_12.pdf: 2 pages
# [INFO] Form 1040 E/Kennedy_22_23.pdf: 2 pages
# [INFO] W9/BlueStone Lane Coffee Events.pdf: 1 pages
# [INFO] W9/submittable_merge_1_3_3.pdf: 1 pages
# [INFO] W9/submittable_merge_1_9_9.pdf: 1 pages
# [INFO] W9/fw9_1_1.pdf: 1 pages
# [INFO] W9/submittable_merge_2_4_4.pdf: 1 pages
# [INFO] Acord 25/two-acord-25_1_1.pdf: 1 pages
# [INFO] Acord 25/acord-28-25_8_8.pdf: 1 pages
# [INFO] Acord 25/two-acord-25_2_2.pdf: 1 pages
# [INFO] Acord 25/acord_25.pdf: 1 pages
#
# === Summary ===
# Invoice/page_19_invoice_10_10.pdf: 1 pages
# Invoice/page_20_invoice_7_7.pdf: 1 pages
# Invoice/page_19_invoice_3_3.pdf: 1 pages
# Invoice/page_20_invoice_17_17.pdf: 1 pages
# Invoice/page_19_invoice_17_17.pdf: 1 pages
# Form 1040/document (25)_2_3.pdf: 2 pages
# Form 1040/2022 UNFILED tax return_2_3.pdf: 2 pages
# Form 1040/form_1040.pdf: 2 pages
# Form 1040/sample_form_1040.pdf: 2 pages
# Form 1040/foxtheresa_22i_FC(1)_10_11.pdf: 2 pages
# Form 1040 A/Heisey, Matthew D_7_7.pdf: 1 pages
# Form 1040 A/document (3)_9_9.pdf: 1 pages
# Form 1040 A/Kennedy_15_15.pdf: 1 pages
# Form 1040 A/2020 Tax Return_9_9.pdf: 1 pages
# Form 1040 A/Reyes 1040 2021_3_3.pdf: 1 pages
# Form 1040 B/sample_form_1040_schedule_b.pdf: 1 pages
# Form 1040 B/2022 Tax Return Documents (Warner Theodore L and J - Client Copy) (3)_8_8.pdf: 1 pages
# Form 1040 B/RJ_Roberts_1040_2021 taxes_13_13.pdf: 1 pages
# Form 1040 B/Dina & Chris combined 1040_6_6.pdf: 1 pages
# Form 1040 B/MARLON and SALLY REYES 2022 Client Copy_9_9.pdf: 1 pages
# Form 1040 C/2022 Tax Return_Acosta, Juan and Jeanette Favela_30_31.pdf: 2 pages
# Form 1040 C/2021 Tax Return Documents (Volovik Inna and Aleksa - Client Copy)_20_21.pdf: 2 pages
# Form 1040 C/document (3)_13_14.pdf: 2 pages
# Form 1040 C/Heisey, Matthew D_9_10.pdf: 2 pages
# Form 1040 C/2022 George Garner_21_22.pdf: 2 pages
# Form 1040 D/2021 Tax Return Documents (Volovik Inna and Aleksa - Client Copy)_24_25.pdf: 2 pages
# Form 1040 D/JEREZ TAX 2021_15_16.pdf: 2 pages
# Form 1040 D/document (3)_removed_16_17.pdf: 2 pages
# Form 1040 D/2022 Tax Return_Acosta, Juan and Jeanette Favela_33_34.pdf: 2 pages
# Form 1040 D/Forgie, Michael_16_17.pdf: 2 pages
# Form 1040 E/2022 Tax Return Documents (MCDONALD STANTON H and) draft_15_16.pdf: 2 pages
# Form 1040 E/GTI to PDF Conversion -- 2ce88f36-eec2-f518-1afa-e0f52c16c359_7_8.pdf: 2 pages
# Form 1040 E/2021.1040.Maciak_18_19.pdf: 2 pages
# Form 1040 E/Heisey, Matthew D_11_12.pdf: 2 pages
# Form 1040 E/Kennedy_22_23.pdf: 2 pages
# W9/BlueStone Lane Coffee Events.pdf: 1 pages
# W9/submittable_merge_1_3_3.pdf: 1 pages
# W9/submittable_merge_1_9_9.pdf: 1 pages
# W9/fw9_1_1.pdf: 1 pages
# W9/submittable_merge_2_4_4.pdf: 1 pages
# Acord 25/two-acord-25_1_1.pdf: 1 pages
# Acord 25/acord-28-25_8_8.pdf: 1 pages
# Acord 25/two-acord-25_2_2.pdf: 1 pages
# Acord 25/acord_25.pdf: 1 pages

# %%
# === CONFIGURATION ===
base_dir = os.getcwd()
min_pages = 150
max_pages = 200
num_merged_files = 20
output_dir = os.path.join(base_dir, "test_real")  # Save all outputs here

# Create output folder if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# === STEP 1: Build a pool of all PDFs with page counts ===
pdf_pool = []  # List of tuples: (doc_type, filepath, page_count)

for folder in folders:
    folder_path = os.path.join(base_dir, folder)
    if not os.path.isdir(folder_path):
        print(f"[WARNING] Folder not found: {folder_path}")
        continue

    for filename in os.listdir(folder_path):
        if filename.lower().endswith(".pdf"):
            file_path = os.path.join(folder_path, filename)
            try:
                doc = fitz.open(file_path)
                page_count = len(doc)
                doc.close()
                pdf_pool.append((folder, file_path, page_count))
            except Exception as e:
                print(f"[ERROR] Failed to open {file_path}: {e}")

print(f"[INFO] Total available PDFs: {len(pdf_pool)}")

# === STEP 2: Generate merged PDFs ===
for file_index in range(1, num_merged_files + 1):
    print(f"\n=== [MERGE {file_index}] Creating merged PDF... ===")
    selected_docs = []
    total_pages = 0
    attempts = 0

    # Pick random target page count between min and max
    target_pages = random.randint(min_pages, max_pages)
    print(f"[INFO] Targeting {target_pages} pages for merged file #{file_index}")

    shuffled_pool = pdf_pool[:]
    random.shuffle(shuffled_pool)

    while total_pages < target_pages and attempts < len(shuffled_pool) * 2:
        for item in shuffled_pool:
            doc_type, path, pages = item
            if total_pages + pages > target_pages:
                continue
            selected_docs.append(item)
            total_pages += pages
            if total_pages >= target_pages:
                break
        attempts += 1

    if not selected_docs:
        print(f"[ERROR] Could not create merged file #{file_index}. Skipping.")
        continue

    output_pdf = fitz.open()
    expanded_lines = []
    merge_log = []
    current_page = 0

    for i, (doc_type, file_path, pages) in enumerate(selected_docs):
        try:
            input_pdf = fitz.open(file_path)
            output_pdf.insert_pdf(input_pdf)
            input_pdf.close()

            expanded_lines.extend([doc_type] * pages)

            start_page = current_page + 1
            end_page = current_page + pages
            page_range = f"{start_page}-{end_page}" if pages > 1 else f"{start_page}"
            merge_log.append(f"Entry {i+1}: {os.path.basename(file_path)} ({doc_type}) → PDF pages {page_range}")
            current_page += pages

        except Exception as e:
            print(f"[ERROR] Failed to process {file_path}: {e}")

    # === STEP 3: Save output files ===
    merged_pdf_name = os.path.join(output_dir, f"merged_output_{file_index}.pdf")
    merged_txt_name = os.path.join(output_dir, f"merged_output_{file_index}.txt")
    merged_log_name = os.path.join(output_dir, f"merged_output_{file_index}_log.txt")

    output_pdf.save(merged_pdf_name)
    output_pdf.close()

    with open(merged_txt_name, "w") as f:
        f.write("\n".join(expanded_lines))

    with open(merged_log_name, "w") as log:
        log.write("\n".join(merge_log))
        log.write(f"\n\nTotal pages in merged PDF: {current_page}")

    print(f"[INFO] Saved: {merged_pdf_name} ({total_pages} pages)")
    print(f"[INFO] Saved: {merged_txt_name}")
    print(f"[INFO] Saved: {merged_log_name}")
# Out:
# [INFO] Total available PDFs: 44
#
# === [MERGE 1] Creating merged PDF... ===
# [INFO] Targeting 168 pages for merged file #1
# [INFO] Saved: /media/veracrypt1/batching_and_comparison/ai_split_optimization/test_real/merged_output_1.pdf (168 pages)
# [INFO] Saved: /media/veracrypt1/batching_and_comparison/ai_split_optimization/test_real/merged_output_1.txt
# [INFO] Saved: /media/veracrypt1/batching_and_comparison/ai_split_optimization/test_real/merged_output_1_log.txt
#
# === [MERGE 2] Creating merged PDF... ===
# [INFO] Targeting 177 pages for merged file #2
# [INFO] Saved: /media/veracrypt1/batching_and_comparison/ai_split_optimization/test_real/merged_output_2.pdf (177 pages)
# [INFO] Saved: /media/veracrypt1/batching_and_comparison/ai_split_optimization/test_real/merged_output_2.txt
# [INFO] Saved: /media/veracrypt1/batching_and_comparison/ai_split_optimization/test_real/merged_output_2_log.txt
#
# === [MERGE 3] Creating merged PDF... ===
# [INFO] Targeting 187 pages for merged file #3
# [INFO] Saved: /media/veracrypt1/batching_and_comparison/ai_split_optimization/test_real/merged_output_3.pdf (187 pages)
# [INFO] Saved: /media/veracrypt1/batching_and_comparison/ai_split_optimization/test_real/merged_output_3.txt
# [INFO] Saved: /media/veracrypt1/batching_and_comparison/ai_split_optimization/test_real/merged_output_3_log.txt
#
# === [MERGE 4] Creating merged PDF... ===
# [INFO] Targeting 196 pages for merged file #4
# [INFO] Saved: /media/veracrypt1/batching_and_comparison/ai_split_optimization/test_real/merged_output_4.pdf (196 pages)
# [INFO] Saved: /media/veracrypt1/batching_and_comparison/ai_split_optimization/test_real/merged_output_4.txt
# [INFO] Saved: /media/veracrypt1/batching_and_comparison/ai_split_optimization/test_real/merged_output_4_log.txt
#
# === [MERGE 5] Creating merged PDF... ===
# [INFO] Targeting 177 pages for merged file #5
# [INFO] Saved: /media/veracrypt1/batching_and_comparison/ai_split_optimization/test_real/merged_output_5.pdf (177 pages)
# [INFO] Saved: /media/veracrypt1/batching_and_comparison/ai_split_optimization/test_real/merged_output_5.txt
# [INFO] Saved: /media/veracrypt1/batching_and_comparison/ai_split_optimization/test_real/merged_output_5_log.txt
#
# === [MERGE 6] Creating merged PDF... ===
# [INFO] Targeting 187 pages for merged file #6
# [INFO] Saved: /media/veracrypt1/batching_and_comparison/ai_split_optimization/test_real/merged_output_6.pdf (187 pages)
# [INFO] Saved: /media/veracrypt1/batching_and_comparison/ai_split_optimization/test_real/merged_output_6.txt
# [INFO] Saved: /media/veracrypt1/batching_and_comparison/ai_split_optimization/test_real/merged_output_6_log.txt
#
# === [MERGE 7] Creating merged PDF... ===
# [INFO] Targeting 161 pages for merged file #7
# [INFO] Saved: /media/veracrypt1/batching_and_comparison/ai_split_optimization/test_real/merged_output_7.pdf (161 pages)
# [INFO] Saved: /media/veracrypt1/batching_and_comparison/ai_split_optimization/test_real/merged_output_7.txt
# [INFO] Saved: /media/veracrypt1/batching_and_comparison/ai_split_optimization/test_real/merged_output_7_log.txt
#
# === [MERGE 8] Creating merged PDF... ===
# [INFO] Targeting 160 pages for merged file #8
# [INFO] Saved: /media/veracrypt1/batching_and_comparison/ai_split_optimization/test_real/merged_output_8.pdf (160 pages)
# [INFO] Saved: /media/veracrypt1/batching_and_comparison/ai_split_optimization/test_real/merged_output_8.txt
# [INFO] Saved: /media/veracrypt1/batching_and_comparison/ai_split_optimization/test_real/merged_output_8_log.txt
#
# === [MERGE 9] Creating merged PDF... ===
# [INFO] Targeting 178 pages for merged file #9
# [INFO] Saved: /media/veracrypt1/batching_and_comparison/ai_split_optimization/test_real/merged_output_9.pdf (178 pages)
# [INFO] Saved: /media/veracrypt1/batching_and_comparison/ai_split_optimization/test_real/merged_output_9.txt
# [INFO] Saved: /media/veracrypt1/batching_and_comparison/ai_split_optimization/test_real/merged_output_9_log.txt
#
# === [MERGE 10] Creating merged PDF... ===
# [INFO] Targeting 183 pages for merged file #10
# [INFO] Saved: /media/veracrypt1/batching_and_comparison/ai_split_optimization/test_real/merged_output_10.pdf (183 pages)
# [INFO] Saved: /media/veracrypt1/batching_and_comparison/ai_split_optimization/test_real/merged_output_10.txt
# [INFO] Saved: /media/veracrypt1/batching_and_comparison/ai_split_optimization/test_real/merged_output_10_log.txt
#
# === [MERGE 11] Creating merged PDF... ===
# [INFO] Targeting 199 pages for merged file #11
# [INFO] Saved: /media/veracrypt1/batching_and_comparison/ai_split_optimization/test_real/merged_output_11.pdf (199 pages)
# [INFO] Saved: /media/veracrypt1/batching_and_comparison/ai_split_optimization/test_real/merged_output_11.txt
# [INFO] Saved: /media/veracrypt1/batching_and_comparison/ai_split_optimization/test_real/merged_output_11_log.txt
#
# === [MERGE 12] Creating merged PDF... ===
# [INFO] Targeting 154 pages for merged file #12
# [INFO] Saved: /media/veracrypt1/batching_and_comparison/ai_split_optimization/test_real/merged_output_12.pdf (154 pages)
# [INFO] Saved: /media/veracrypt1/batching_and_comparison/ai_split_optimization/test_real/merged_output_12.txt
# [INFO] Saved: /media/veracrypt1/batching_and_comparison/ai_split_optimization/test_real/merged_output_12_log.txt
#
# === [MERGE 13] Creating merged PDF... ===
# [INFO] Targeting 167 pages for merged file #13
# [INFO] Saved: /media/veracrypt1/batching_and_comparison/ai_split_optimization/test_real/merged_output_13.pdf (167 pages)
# [INFO] Saved: /media/veracrypt1/batching_and_comparison/ai_split_optimization/test_real/merged_output_13.txt
# [INFO] Saved: /media/veracrypt1/batching_and_comparison/ai_split_optimization/test_real/merged_output_13_log.txt
#
# === [MERGE 14] Creating merged PDF... ===
# [INFO] Targeting 183 pages for merged file #14
# [INFO] Saved: /media/veracrypt1/batching_and_comparison/ai_split_optimization/test_real/merged_output_14.pdf (183 pages)
# [INFO] Saved: /media/veracrypt1/batching_and_comparison/ai_split_optimization/test_real/merged_output_14.txt
# [INFO] Saved: /media/veracrypt1/batching_and_comparison/ai_split_optimization/test_real/merged_output_14_log.txt
#
# === [MERGE 15] Creating merged PDF... ===
# [INFO] Targeting 150 pages for merged file #15
# [INFO] Saved: /media/veracrypt1/batching_and_comparison/ai_split_optimization/test_real/merged_output_15.pdf (150 pages)
# [INFO] Saved: /media/veracrypt1/batching_and_comparison/ai_split_optimization/test_real/merged_output_15.txt
# [INFO] Saved: /media/veracrypt1/batching_and_comparison/ai_split_optimization/test_real/merged_output_15_log.txt
#
# === [MERGE 16] Creating merged PDF... ===
# [INFO] Targeting 154 pages for merged file #16
# [INFO] Saved: /media/veracrypt1/batching_and_comparison/ai_split_optimization/test_real/merged_output_16.pdf (154 pages)
# [INFO] Saved: /media/veracrypt1/batching_and_comparison/ai_split_optimization/test_real/merged_output_16.txt
# [INFO] Saved: /media/veracrypt1/batching_and_comparison/ai_split_optimization/test_real/merged_output_16_log.txt
#
# === [MERGE 17] Creating merged PDF... ===
# [INFO] Targeting 182 pages for merged file #17
# [INFO] Saved: /media/veracrypt1/batching_and_comparison/ai_split_optimization/test_real/merged_output_17.pdf (182 pages)
# [INFO] Saved: /media/veracrypt1/batching_and_comparison/ai_split_optimization/test_real/merged_output_17.txt
# [INFO] Saved: /media/veracrypt1/batching_and_comparison/ai_split_optimization/test_real/merged_output_17_log.txt
#
# === [MERGE 18] Creating merged PDF... ===
# [INFO] Targeting 189 pages for merged file #18
# [INFO] Saved: /media/veracrypt1/batching_and_comparison/ai_split_optimization/test_real/merged_output_18.pdf (189 pages)
# [INFO] Saved: /media/veracrypt1/batching_and_comparison/ai_split_optimization/test_real/merged_output_18.txt
# [INFO] Saved: /media/veracrypt1/batching_and_comparison/ai_split_optimization/test_real/merged_output_18_log.txt
#
# === [MERGE 19] Creating merged PDF... ===
# [INFO] Targeting 192 pages for merged file #19
# [INFO] Saved: /media/veracrypt1/batching_and_comparison/ai_split_optimization/test_real/merged_output_19.pdf (192 pages)
# [INFO] Saved: /media/veracrypt1/batching_and_comparison/ai_split_optimization/test_real/merged_output_19.txt
# [INFO] Saved: /media/veracrypt1/batching_and_comparison/ai_split_optimization/test_real/merged_output_19_log.txt
#
# === [MERGE 20] Creating merged PDF... ===
# [INFO] Targeting 152 pages for merged file #20
# [INFO] Saved: /media/veracrypt1/batching_and_comparison/ai_split_optimization/test_real/merged_output_20.pdf (152 pages)
# [INFO] Saved: /media/veracrypt1/batching_and_comparison/ai_split_optimization/test_real/merged_output_20.txt
# [INFO] Saved: /media/veracrypt1/batching_and_comparison/ai_split_optimization/test_real/merged_output_20_log.txt

# %% [markdown]
# ### This code is only done for doing parsing purpose you can skip sections below it

# %%
def get_google_ocr_raw_data(file_path: str) -> Tuple[List[np.array], List[pd.DataFrame]]:
    df_list = []
    image_list = []
    if file_path.endswith("pdf"):
        images = PdfImages(file_path)
    else:
        images = [cv2.imread(file_path)]
    for index,image in enumerate(images):
        (df, cdf), (image, angle) = read_everything(image)
        df_list.append(df)
        image_list.append(image)


    return image_list, df_list

image_list, df_list = get_google_ocr_raw_data("path_to_one_of_your_pdf_file")
# Out:
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# Syntax Warning: Bad bounding box in Type 3 glyph
# ...
# 2025-05-01 12:13:08.741 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:356 - 0.0
# 2025-05-01 12:13:08.742 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:362 - Using 4-point rotation transformation.
# 2025-05-01 12:13:08.828 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:345 - Reading data using Google OCR
# 2025-05-01 12:13:08.832 | INFO     | docsumo_image_util.parse.ocr.google:read_raw:116 - Using Google OCR provider
# 2025-05-01 12:13:11.098 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:348 - Parsing responses with four points
# 2025-05-01 12:13:11.544 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:356 - 0.0
# 2025-05-01 12:13:11.545 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:362 - Using 4-point rotation transformation.
# 2025-05-01 12:13:11.656 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:345 - Reading data using Google OCR
# 2025-05-01 12:13:11.657 | INFO     | docsumo_image_util.parse.ocr.google:read_raw:116 - Using Google OCR provider
# 2025-05-01 12:13:13.752 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:348 - Parsing responses with four points
# 2025-05-01 12:13:14.022 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:356 - 0.0
# 2025-05-01 12:13:14.023 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:362 - Using 4-point rotation transformation.
# 2025-05-01 12:13:14.131 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:345 - Reading data using Google OCR
# 2025-05-01 12:13:14.133 | INFO     | docsumo_image_util.parse.ocr.google:read_raw:116 - Using Google OCR provider
# 2025-05-01 12:13:16.786 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:348 - Parsing responses with four points
# 2025-05-01 12:13:17.233 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:356 - 0.0
# 2025-05-01 12:13:17.235 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:362 - Using 4-point rotation transformation.
# 2025-05-01 12:13:17.356 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:345 - Reading data using Google OCR
# 2025-05-01 12:13:17.357 | INFO     | docsumo_image_util.parse.ocr.google:read_raw:116 - Using Google OCR provider
# 2025-05-01 12:13:19.457 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:348 - Parsing responses with four points
# 2025-05-01 12:13:19.798 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:356 - 0.0
# 2025-05-01 12:13:19.800 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:362 - Using 4-point rotation transformation.
# 2025-05-01 12:13:19.915 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:345 - Reading data using Google OCR
# 2025-05-01 12:13:19.917 | INFO     | docsumo_image_util.parse.ocr.google:read_raw:116 - Using Google OCR provider
# 2025-05-01 12:13:21.662 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:348 - Parsing responses with four points
# 2025-05-01 12:13:21.929 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:356 - 0.0
# 2025-05-01 12:13:21.931 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:362 - Using 4-point rotation transformation.
# 2025-05-01 12:13:22.026 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:345 - Reading data using Google OCR
# 2025-05-01 12:13:22.029 | INFO     | docsumo_image_util.parse.ocr.google:read_raw:116 - Using Google OCR provider
# 2025-05-01 12:13:24.245 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:348 - Parsing responses with four points
# 2025-05-01 12:13:24.637 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:356 - 0.0
# 2025-05-01 12:13:24.638 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:362 - Using 4-point rotation transformation.
# 2025-05-01 12:13:24.753 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:345 - Reading data using Google OCR
# 2025-05-01 12:13:24.755 | INFO     | docsumo_image_util.parse.ocr.google:read_raw:116 - Using Google OCR provider
# 2025-05-01 12:13:26.723 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:348 - Parsing responses with four points
# 2025-05-01 12:13:26.982 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:356 - 0.0
# 2025-05-01 12:13:26.984 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:362 - Using 4-point rotation transformation.
# 2025-05-01 12:13:27.099 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:345 - Reading data using Google OCR
# 2025-05-01 12:13:27.101 | INFO     | docsumo_image_util.parse.ocr.google:read_raw:116 - Using Google OCR provider
# 2025-05-01 12:13:29.159 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:348 - Parsing responses with four points
# 2025-05-01 12:13:29.436 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:356 - 0.0
# 2025-05-01 12:13:29.438 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:362 - Using 4-point rotation transformation.
# 2025-05-01 12:13:29.546 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:345 - Reading data using Google OCR
# 2025-05-01 12:13:29.548 | INFO     | docsumo_image_util.parse.ocr.google:read_raw:116 - Using Google OCR provider
# 2025-05-01 12:13:31.544 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:348 - Parsing responses with four points
# 2025-05-01 12:13:31.834 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:356 - 0.0
# 2025-05-01 12:13:31.836 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:362 - Using 4-point rotation transformation.
# 2025-05-01 12:13:31.938 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:345 - Reading data using Google OCR
# 2025-05-01 12:13:31.941 | INFO     | docsumo_image_util.parse.ocr.google:read_raw:116 - Using Google OCR provider
# 2025-05-01 12:13:33.848 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:348 - Parsing responses with four points
# 2025-05-01 12:13:34.142 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:356 - 0.0
# 2025-05-01 12:13:34.144 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:362 - Using 4-point rotation transformation.
# 2025-05-01 12:13:34.257 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:345 - Reading data using Google OCR
# 2025-05-01 12:13:34.259 | INFO     | docsumo_image_util.parse.ocr.google:read_raw:116 - Using Google OCR provider
# 2025-05-01 12:13:36.967 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:348 - Parsing responses with four points
# 2025-05-01 12:13:37.395 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:356 - 0.0
# 2025-05-01 12:13:37.396 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:362 - Using 4-point rotation transformation.
# 2025-05-01 12:13:37.515 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:345 - Reading data using Google OCR
# 2025-05-01 12:13:37.517 | INFO     | docsumo_image_util.parse.ocr.google:read_raw:116 - Using Google OCR provider
# 2025-05-01 12:13:39.736 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:348 - Parsing responses with four points
# 2025-05-01 12:13:40.069 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:356 - 0.0
# 2025-05-01 12:13:40.071 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:362 - Using 4-point rotation transformation.
# 2025-05-01 12:13:40.193 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:345 - Reading data using Google OCR
# 2025-05-01 12:13:40.195 | INFO     | docsumo_image_util.parse.ocr.google:read_raw:116 - Using Google OCR provider
# 2025-05-01 12:13:41.947 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:348 - Parsing responses with four points
# 2025-05-01 12:13:42.232 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:356 - 0.0
# 2025-05-01 12:13:42.234 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:362 - Using 4-point rotation transformation.
# 2025-05-01 12:13:42.338 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:345 - Reading data using Google OCR
# 2025-05-01 12:13:42.340 | INFO     | docsumo_image_util.parse.ocr.google:read_raw:116 - Using Google OCR provider
# 2025-05-01 12:13:44.852 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:348 - Parsing responses with four points
# 2025-05-01 12:13:45.180 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:356 - 0.0
# 2025-05-01 12:13:45.182 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:362 - Using 4-point rotation transformation.
# 2025-05-01 12:13:45.296 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:345 - Reading data using Google OCR
# 2025-05-01 12:13:45.298 | INFO     | docsumo_image_util.parse.ocr.google:read_raw:116 - Using Google OCR provider
# 2025-05-01 12:13:47.586 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:348 - Parsing responses with four points
# 2025-05-01 12:13:47.882 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:356 - 0.0
# 2025-05-01 12:13:47.884 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:362 - Using 4-point rotation transformation.
# 2025-05-01 12:13:47.983 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:345 - Reading data using Google OCR
# 2025-05-01 12:13:47.986 | INFO     | docsumo_image_util.parse.ocr.google:read_raw:116 - Using Google OCR provider
# 2025-05-01 12:13:50.168 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:348 - Parsing responses with four points
# 2025-05-01 12:13:50.409 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:356 - 0.0
# 2025-05-01 12:13:50.411 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:362 - Using 4-point rotation transformation.
# 2025-05-01 12:13:50.510 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:345 - Reading data using Google OCR
# 2025-05-01 12:13:50.512 | INFO     | docsumo_image_util.parse.ocr.google:read_raw:116 - Using Google OCR provider
# 2025-05-01 12:13:52.641 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:348 - Parsing responses with four points
# 2025-05-01 12:13:52.902 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:356 - 0.0
# 2025-05-01 12:13:52.903 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:362 - Using 4-point rotation transformation.
# 2025-05-01 12:13:53.002 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:345 - Reading data using Google OCR
# 2025-05-01 12:13:53.004 | INFO     | docsumo_image_util.parse.ocr.google:read_raw:116 - Using Google OCR provider
# 2025-05-01 12:13:54.846 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:348 - Parsing responses with four points
# 2025-05-01 12:13:54.973 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:356 - 0.0
# 2025-05-01 12:13:54.975 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:362 - Using 4-point rotation transformation.
# 2025-05-01 12:13:55.051 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:345 - Reading data using Google OCR
# 2025-05-01 12:13:55.053 | INFO     | docsumo_image_util.parse.ocr.google:read_raw:116 - Using Google OCR provider
# 2025-05-01 12:13:56.875 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:348 - Parsing responses with four points
# 2025-05-01 12:13:57.168 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:356 - 0.0
# 2025-05-01 12:13:57.170 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:362 - Using 4-point rotation transformation.
# 2025-05-01 12:13:57.274 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:345 - Reading data using Google OCR
# 2025-05-01 12:13:57.276 | INFO     | docsumo_image_util.parse.ocr.google:read_raw:116 - Using Google OCR provider
# 2025-05-01 12:13:59.623 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:348 - Parsing responses with four points
# 2025-05-01 12:13:59.987 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:356 - 0.0
# 2025-05-01 12:13:59.989 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:362 - Using 4-point rotation transformation.
# 2025-05-01 12:14:00.113 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:345 - Reading data using Google OCR
# 2025-05-01 12:14:00.115 | INFO     | docsumo_image_util.parse.ocr.google:read_raw:116 - Using Google OCR provider
# 2025-05-01 12:14:01.943 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:348 - Parsing responses with four points
# 2025-05-01 12:14:02.212 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:356 - 0.0
# 2025-05-01 12:14:02.213 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:362 - Using 4-point rotation transformation.
# 2025-05-01 12:14:02.315 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:345 - Reading data using Google OCR
# 2025-05-01 12:14:02.317 | INFO     | docsumo_image_util.parse.ocr.google:read_raw:116 - Using Google OCR provider
# 2025-05-01 12:14:03.964 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:348 - Parsing responses with four points
# 2025-05-01 12:14:04.215 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:356 - 0.0
# 2025-05-01 12:14:04.216 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:362 - Using 4-point rotation transformation.
# 2025-05-01 12:14:04.314 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:345 - Reading data using Google OCR
# 2025-05-01 12:14:04.316 | INFO     | docsumo_image_util.parse.ocr.google:read_raw:116 - Using Google OCR provider
# 2025-05-01 12:14:06.317 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:348 - Parsing responses with four points
# 2025-05-01 12:14:06.444 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:356 - 0.0
# 2025-05-01 12:14:06.445 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:362 - Using 4-point rotation transformation.
# 2025-05-01 12:14:06.509 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:345 - Reading data using Google OCR
# 2025-05-01 12:14:06.511 | INFO     | docsumo_image_util.parse.ocr.google:read_raw:116 - Using Google OCR provider
# 2025-05-01 12:14:08.333 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:348 - Parsing responses with four points
# 2025-05-01 12:14:08.613 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:356 - 0.0
# 2025-05-01 12:14:08.615 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:362 - Using 4-point rotation transformation.
# 2025-05-01 12:14:08.720 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:345 - Reading data using Google OCR
# 2025-05-01 12:14:08.722 | INFO     | docsumo_image_util.parse.ocr.google:read_raw:116 - Using Google OCR provider
# 2025-05-01 12:14:11.308 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:348 - Parsing responses with four points
# 2025-05-01 12:14:11.738 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:356 - 0.0
# 2025-05-01 12:14:11.739 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:362 - Using 4-point rotation transformation.
# 2025-05-01 12:14:11.867 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:345 - Reading data using Google OCR
# 2025-05-01 12:14:11.869 | INFO     | docsumo_image_util.parse.ocr.google:read_raw:116 - Using Google OCR provider
# 2025-05-01 12:14:14.275 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:348 - Parsing responses with four points
# 2025-05-01 12:14:14.726 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:356 - 0.0
# 2025-05-01 12:14:14.729 | INFO     | docsumo_image_util.parse.ocr.google:read_everything:362 - Using 4-point rotation transformation.

# %%
for i, df in enumerate(df_list):
    df['page'] = i  # or i + 1 if you want to start from 1 instead of 0

# %%
final_df = pd.concat(df_list).reset_index(drop=True)

# %%
final_df
# Out:
#         index_sort  page  block  line    x0    y0    x2    y2         Text  \
# 0                0     0      0     0    64    71   238   105        ACORD
# 1                1     0      1     0   237    71   251    83            Ⓡ
# 2                2     0      2     0   453    84   709   114  CERTIFICATE
# 3                3     0      2     0   722    84   774   114           OF
# 4                4     0      2     0   787    84   971   114    LIABILITY
# ...            ...   ...    ...   ...   ...   ...   ...   ...          ...
# 106663        1122   174     45     5   883  2073   930  2090       later.
# 106664        1123   174     46     0  1371  2116  1415  2138         Form
# 106665        1126   174     46     0  1421  2116  1474  2138          W-9
# 106666        1128   174     46     0  1480  2117  1526  2138        (Rev.
# 106667        1130   174     46     0  1530  2117  1608  2140     10-2018)
#
#         space_type  confidence
# 0                5    0.989440
# 1                5    0.431050
# 2                1    0.993090
# 3                1    0.979886
# 4                1    0.990620
# ...            ...         ...
# 106663           5    0.973015
# 106664           1    0.977495
# 106665           1    0.965322
# 106666           1    0.973602
# 106667           5    0.980159
#
# [106668 rows x 11 columns]
